# %% [markdown]
# <a href="https://colab.research.google.com/github/wallflower25-ai/Snehal/blob/main/DMWLab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install apyori
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=0d9f1cb1b654be1e3bda7af5a95566704c87d000ad9f950303246c11f6385896
#   Stored in directory: /root/.cache/pip/wheels/1b/02/6c/a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
df = pd.read_csv("Stationery.csv")

# %%
df.head()
# Out:
#    ID    Name     Item1      Item2      Item3  Item4  Bill
# 0   1  Tushar    Pencil     Eraser   Sharpner    NaN    20
# 1   2  Ramesh       Pen      Pages      Files    Gum    65
# 2   3  Pankaj    Eraser    Perfume  Chocolate    NaN    40
# 3   4  Kartik     Pages      Files    Stapler  Scale   110
# 4   5  Ganesh  Biscuits  Chocolate        NaN    NaN    15

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Item1     0
# Item2     2
# Item3     6
# Item4    16
# Bill      0
# dtype: int64

# %%
df1 = df[['Item1','Item2','Item3','Item4']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      23 non-null     int64
#  1   Name    23 non-null     object
#  2   Item1   23 non-null     object
#  3   Item2   21 non-null     object
#  4   Item3   17 non-null     object
#  5   Item4   7 non-null      object
#  6   Bill    23 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ KB

# %%
df1.head()
# Out:
#       Item1      Item2      Item3  Item4
# 0    Pencil     Eraser   Sharpner    NaN
# 1       Pen      Pages      Files    Gum
# 2    Eraser    Perfume  Chocolate    NaN
# 3     Pages      Files    Stapler  Scale
# 4  Biscuits  Chocolate        NaN    NaN

# %%
records = []
for i in range(23):
    records.append([str(df1.values[i, j]) for j in range(0, 4)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'Eraser', 'Sharpner'})
# frozenset({'Files', 'Stapler'})
# frozenset({'Scale', 'Gum'})
# frozenset({'Gum', 'Sheets'})
# frozenset({'Pages', 'Stapler'})
# frozenset({'Sharpner', 'Pencil'})
# frozenset({'Scale', 'Stapler'})
# frozenset({'Chocolate', 'Pencil', 'Biscuits'})
# frozenset({'Chocolate', 'Biscuits', 'Scale'})
# frozenset({'Chocolate', 'nan', 'Biscuits'})
# frozenset({'Chocolate', 'Files', 'Compass'})
# frozenset({'Chocolate', 'Eraser', 'Perfume'})
# frozenset({'Pages', 'Compass', 'Files'})
# frozenset({'Pen', 'Compass', 'Files'})
# frozenset({'Compass', 'Gum', 'Scale'})
# frozenset({'Compass', 'Gum', 'Sheets'})
# frozenset({'Compass', 'Scale', 'Sheets'})
# frozenset({'Pen', 'Eraser', 'Pencil'})
# frozenset({'Pen', 'Eraser', 'Sharpner'})
# frozenset({'Eraser', 'Sharpner', 'Pencil'})
# frozenset({'Eraser', 'nan', 'Perfume'})
# frozenset({'Eraser', 'nan', 'Sharpner'})
# frozenset({'Pages', 'Files', 'Gum'})
# frozenset({'Pen', 'Files', 'Gum'})
# ...

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Eraser -> Sharpner
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# ...
# Rule: Files -> Stapler
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# ...
# Rule: Scale -> Gum
# Support: 0.08695652173913043
# Confidence: 0.6666666666666666
# Lift: 3.0666666666666664
# ...
# Rule: Gum -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# ...
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# ...
# Rule: Sharpner -> Pencil
# Support: 0.13043478260869565
# Confidence: 0.42857142857142855
# Lift: 3.2857142857142856
# ...
# Rule: Scale -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# ...
# Rule: Chocolate -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# ...
# Rule: Chocolate -> Biscuits
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# ...
# Rule: Chocolate -> nan
# ...
